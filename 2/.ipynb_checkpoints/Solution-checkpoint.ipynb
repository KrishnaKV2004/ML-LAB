# %% [markdown]
# ### Problem Statement
#
# 1. Create a dataset with one categorical feature[Gender] with some None values,
#    one numerical feature[Age] with some Nan values.
# 2. Impute The Gender Column with the mode of the column and Age column with mean.
# 3. Visualize the data before and after imputation.

# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Generating Dataset

# %%
gender_choices = ["Male", "Female", None]

data = {
    "Gender": [np.random.choice(gender_choices) for _ in range(100)],
    "Age": [np.random.choice([25, 30, 45, 50, 22, 27, 40, np.nan]) for _ in range(100)]
}

data = pd.DataFrame(data)
data
# Out:
#     Gender   Age
# 0   Female   NaN
# 1     None  27.0
# 2     Male  50.0
# 3   Female  45.0
# 4     None  40.0
# ..     ...   ...
# 95  Female  22.0
# 96    None  22.0
# 97    None  30.0
# 98    None  40.0
# 99    None  50.0
#
# [100 rows x 2 columns]

# %% [markdown]
# ### Before Imputation

# %%
plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
sns.countplot(data=data, x='Gender')
plt.title("Gender Distribution Before Imputation")

plt.subplot(1, 2, 2)
sns.histplot(data['Age'].dropna(), kde=True)
plt.title("Age Distribution Before Imputation")
plt.show()

# %% [markdown]
# ### Imputation

# %%
data['Gender'] = data['Gender'].fillna(data['Gender'].mode()[0])
data['Age'] = data['Age'].fillna(data['Age'].mean())
data
# Out:
#     Gender        Age
# 0   Female  34.011111
# 1   Female  27.000000
# 2     Male  50.000000
# 3   Female  45.000000
# 4   Female  40.000000
# ..     ...        ...
# 95  Female  22.000000
# 96  Female  22.000000
# 97  Female  30.000000
# 98  Female  40.000000
# 99  Female  50.000000
#
# [100 rows x 2 columns]

# %%
print(data.isnull().sum())
# Out:
# Gender    0
# Age       0
# dtype: int64

# %% [markdown]
# ### After Imputation

# %%
plt.figure(figsize=(14, 6))
plt.subplot(1, 2, 1)
sns.countplot(data=data, x='Gender')
plt.title("Gender Distribution After Imputation")

plt.subplot(1, 2, 2)
sns.histplot(data['Age'], kde=True)
plt.title("Age Distribution After Imputation")
plt.show()
